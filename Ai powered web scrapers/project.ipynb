# %%
from openai import OpenAI
from scraper import fetch_website_contents
from IPython.display import Markdown, display, update_display

## Prerequisites
# 1. Install Ollama from https://ollama.com/download (Windows/Mac/Linux)
# 2. Start it — it usually runs automatically after install. If not, run `ollama serve` in a terminal and leave it running.
# 3. Pull the model this project uses:
#    ollama pull deepseek-r1:1.5b


system_prompt = """
You are a ruthlessly pragmatic financial advisor and tech critic. Your goal is to aggressively roast e-commerce products and stop the user from making impulse purchases. 
Ignore all marketing hype. Be witty, blunt, and highly sarcastic. Format your response cleanly in Markdown without any introductory pleasantries.
"""

# Define our user prompt

user_prompt_prefix = """
Analyze the following product page content. 

1. Extract a bulleted list of the actual technical specifications (ignore buzzwords).
2. Roast the marketing hype.
3. Provide three brutal, logical reasons why I do not need to buy this right now.

"""


def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    OLLAMA_BASE_URL = "http://localhost:11434/v1"
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    website = fetch_website_contents(url)
    stream = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website),
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    # Print each word the moment the model generates it
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.startech.com.bd/lenovo-ideapad-1-15amn7-ryzen-5-laptop")
# Out:
# ### Technical Specifications
# * Processor: AMD Ryzen 5
# * Motherboard: Not specified
# * Graphics Card: Not specified
# * RAM: Not specified (laptop RAM specifications not available)
# * Storage: Not specified (hard disk drive and SSD specifications not available)
# * Display: Not specified (resolution, size, and type not available)
# * Keyboard: Not specified (key type, layout, and connectivity not available)
# * Operating System: Not specified (Windows or any other operating system not available)
# * Power Supply: Not specified (watts, voltage, and connectivity not available)
#
# ### Roast Marketing Hype
#
# * A Ryzen 5 laptop is no longer considered fast. It's now considered mid-range.
# * Who needs 512 GB of RAM in a laptop? It's almost not enough for most users.
# * The lack of any official operating system details is a glaring omission. Is this thing running Windows 3.0 by any chance?
# * The "Premium Ultrabook" label is a marketing term, not a technical specification.
#
# ### Brutal Reasons to Buy This Laptop Now
#
# 1. **You Need It for a Specific Task**: If you're a professional video editor or 3D artist, you might need a laptop with some actual specifications. In this case, the Ryzen 5 could be considered sufficient for some tasks. However, for most users, it's unlikely to be the right choice.
# 2. **You Refuse to Read Reviews**: Are you a person who thinks they can tell if a laptop is good or bad just by looking at the product page? If so, you might as well buy this thing and hope for the best.
# 3. **You Have Deep Pockets**: If you're willing to throw money at a product just because it's "special deals" material, then this might be the laptop for you. Unfortunately, this reasoning will eventually lead to buyer's remorse, but hey, at least you got a good story out of it.

# %%
from openai import OpenAI
from scraper import fetch_website_contents
from IPython.display import Markdown, display, update_display

## Prerequisites
# 1. Install Ollama from https://ollama.com/download (Windows/Mac/Linux)
# 2. Start it — it usually runs automatically after install. If not, run `ollama serve` in a terminal and leave it running.
# 3. Pull the model this project uses:
#    ollama pull qwen3.5:4b


system_prompt = """
You are an elite, no-nonsense competitive programming parser. Your sole purpose is to bypass all narrative lore in coding problems and extract only the cold, 
hard mathematical and algorithmic requirements. Be direct and concise. Format strictly in Markdown.
"""

# Define our user prompt

user_prompt_prefix = """
Analyze the following competitive programming problem. Strip away all story elements, character names, and lore. 

Provide exactly the following:
- **Core Challenge:** 1-2 sentences explaining the exact algorithmic task.
- **Inputs:** The explicit input format and data types.
- **Outputs:** The explicit output format.
- **Constraints:** A concise bulleted list of all time, space, and variable limits.

"""


def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    OLLAMA_BASE_URL = "http://localhost:11434/v1"
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    website = fetch_website_contents(url)
    stream = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website),
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    # Print each word the moment the model generates it
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://leetcode.com/problems/maximum-distance-between-a-pair-of-values/description/")
# Out:
# **Problem Analysis**
#
# ### Core Challenge
#
# Generate all permutations of a given string.
#
# ### Inputs
#
# * `chars`: string of unique characters (no spaces or special characters)
# * `length`: integer representing the length of the string
# * `start`: integer (1-indexed) representing the starting index for permutations
#
# ### Outputs
#
# * An array of strings representing all permutations
#
# ### Constraints
#
# * `1 <= length <= 100`
# * `1 <= start <= length`
# * `chars` has at most `length` unique characters
# * The number of permutations may exceed the maximum recursion depth (avoid using recursive solutions with large inputs)
# * Memory usage may be limited (avoid using extremely large data structures)

# %%
from openai import OpenAI
from scraper import fetch_website_contents
from IPython.display import Markdown, display, update_display

## Prerequisites
# 1. Install Ollama from https://ollama.com/download (Windows/Mac/Linux)
# 2. Start it — it usually runs automatically after install. If not, run `ollama serve` in a terminal and leave it running.
# 3. Pull the model this project uses:
#    ollama pull qwen3.5:4b


system_prompt = """
You are a hyper-efficient gaming assistant focused strictly on optimizing in-game currency and rewards. 
You ignore game lore, storyline dialogue, and promotional filler. Output strictly formatted, actionable checklists.
"""

# Define our user prompt

user_prompt_prefix = """
Analyze the following Genshin Impact event or patch notes. Ignore all character dialogue and story summaries. 

Extract the following details:
- **Total Primogems:** The absolute maximum number of Primogems available.
- **Prerequisites:** Any required Adventure Rank, previous quests, or energy thresholds to participate.
- **Actionable Checklist:** A bulleted to-do list of the exact actions required to claim all rewards and character ascension materials.
- **Deadlines:** The end dates for the events.

"""


def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    OLLAMA_BASE_URL = "http://localhost:11434/v1"
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    website = fetch_website_contents(url)
    stream = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website),
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    # Print each word the moment the model generates it
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://genshin.hoyoverse.com/en/news/detail/164999")
# Out:
# **Genshin Impact - Step into a Vast Magical World for Adventure**
#
# **Total Primogems:** 1408
#
# **Prerequisites:**
#
# * Adventure Rank 50+
# * 20-400 Energy
#
# **Actionable Checklist:**
#
# • **Quest Completion:** Complete the "A Story Unfolds" Quest (Level 35)
# • **Labyrinth Rewards:** Participate in the Labyrinth of the Three Realms ( Multiple runs from Week 1-8)
# • **Event Completion:** Complete the Main Quest to unlock event rewards
# • **Childe Ascension:** Ascend Childe to 5 Stars
# • **Elemental Mastery Materials:** Gather and use 1000 Elemental Mastery Materials
# • **Primo Rewards:** Spend 2000-4000 Primogems to complete event rewards and bonuses at the Primogem Store
# • **Daily Rewards:** Participate daily from Week 1-8 to collect bonus rewards at certain intervals
#
# **Deadlines:**
#
# * Week 1-8: Participate in Labyrinth of the Three Realms for rewards; complete event quests and ascension goals before Week 9
# * Week 9 and 10:  Finalize event rewards and bonuses using Primogems at the Primogem Store
# * Ongoing: Complete daily rewards to collect bonus rewards
